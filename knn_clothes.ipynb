# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# CSV-Datei laden
data = pd.read_csv('Data/clothes.csv')
data.head()
# Out:
#    weight   age  height size
# 0      62  28.0  172.72   XL
# 1      59  36.0  167.64    L
# 2      61  34.0  165.10    M
# 3      65  27.0  175.26    L
# 4      62  45.0  172.72    M

# %% [markdown]
# ## Visualisierung der Daten

# %%
wsdata=data[data["size"]=="S"]
wmdata=data[data["size"]=="M"]
wldata=data[data["size"]=="L"]
wxldata=data[data["size"]=="XL"]
wxxldata=data[data["size"]=="XXL"]
wxxxldata=data[data["size"]=="XXXL"]

plt.scatter(wsdata['height'], wsdata['weight'],alpha=0.1, label="S")
plt.scatter(wmdata['height'], wmdata['weight'],alpha=0.1, label="M")
plt.scatter(wldata['height'], wldata['weight'],alpha=0.1, label="L")
plt.scatter(wxldata['height'], wxldata['weight'],alpha=0.1, label="XL")
plt.scatter(wxxldata['height'], wxxldata['weight'],alpha=0.1, label="XXL")
plt.scatter(wxxxldata['height'], wxxxldata['weight'],alpha=0.1, label="XXXL")
   
# Achsenbeschriftungen hinzufügen
plt.xlabel('Height')
plt.ylabel('Weight')

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.show()

# %%
wsdata = data[data["size"] == "S"]
wmdata = data[data["size"] == "M"]
wldata = data[data["size"] == "L"]
wxldata = data[data["size"] == "XL"]
wxxldata = data[data["size"] == "XXL"]
wxxxldata = data[data["size"] == "XXXL"]

plt.scatter(wsdata['age'], wsdata['weight'], alpha=0.1, label="S")
plt.scatter(wmdata['age'], wmdata['weight'], alpha=0.1, label="M")
plt.scatter(wldata['age'], wldata['weight'], alpha=0.1, label="L")
plt.scatter(wxldata['age'], wxldata['weight'], alpha=0.1, label="XL")
plt.scatter(wxxldata['age'], wxxldata['weight'], alpha=0.1, label="XXL")
plt.scatter(wxxxldata['age'], wxxxldata['weight'], alpha=0.1, label="XXXL")

# Achsenbeschriftungen hinzufügen
plt.xlabel('Age')
plt.ylabel('Weight')

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.show()

# %%
wsdata = data[data["size"] == "S"]
wmdata = data[data["size"] == "M"]
wldata = data[data["size"] == "L"]
wxldata = data[data["size"] == "XL"]
wxxldata = data[data["size"] == "XXL"]
wxxxldata = data[data["size"] == "XXXL"]

plt.scatter(wsdata['height'], wsdata['age'], alpha=0.1, label="S")
plt.scatter(wmdata['height'], wmdata['age'], alpha=0.1, label="M")
plt.scatter(wldata['height'], wldata['age'], alpha=0.1, label="L")
plt.scatter(wxldata['height'], wxldata['age'], alpha=0.1, label="XL")
plt.scatter(wxxldata['height'], wxxldata['age'], alpha=0.1, label="XXL")
plt.scatter(wxxxldata['height'], wxxxldata['age'], alpha=0.1, label="XXXL")

# Achsenbeschriftungen hinzufügen
plt.xlabel('Height')
plt.ylabel('Age')

# Legende hinzufügen
plt.legend()

# Plot anzeigen
plt.show()

# %% [markdown]
# ## Bereinigen der Daten

# %%
# remove all ages > 100
data = data[data["age"] <= 100]

# remove NaN values
data = data.dropna()

# %% [markdown]
# ## KNN Analyse durchführen

# %%
# Split data into training and test data
# %pip install scikit-learn
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Train knn model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(train_data[['height', 'weight', 'age']], train_data['size'])

# Test knn model
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(test_data['size'], knn.predict(test_data[['height', 'weight', 'age']]))
print(accuracy)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# 0.47393384822028206

# %% [markdown]
# ## Modell testen

# %%
age = 56
height = 185
weight = 98

pdata = [[age,height,weight]]
knn.predict(pdata)
# Out:
# c:\Users\jtutt\anaconda3\envs\gymenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['XXXL'], dtype=object)
